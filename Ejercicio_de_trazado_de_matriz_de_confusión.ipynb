# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
matrix = np.array([[87, 16], [17, 59]])
matrix
# Out:
# array([[87, 16],
#        [17, 59]])

# %%
resultado = (87 + 59) / (87 + 59 + 17 + 16)
plt.figure(figsize=(9,9))
sns.heatmap(matrix, annot=True,
            fmt=".0f",
            linewidths=.5,
            square = True,
            cmap = 'Blues');
plt.ylabel('Actual label', fontsize = 17);
plt.xlabel('Predicted label', fontsize = 17);
plt.title('Accuracy Score: {}'.format(resultado), size = 17);
plt.tick_params(labelsize= 15)

# %%
plt.figure(figsize=(9,9))
sns.heatmap(matrix, annot=True,
            fmt=".0f",
            linewidths=.5,
            square = True,
            cmap = 'Blues');
plt.ylabel('Actual label', fontsize = 17);
plt.xlabel('Predicted label', fontsize = 17);
plt.title('Accuracy Score: {}'.format(resultado), size = 17);
plt.tick_params(labelsize= 15)
b, t = plt.ylim() #descubrir valores
b += 0.5 #agregar 0.5 abajo
t -= 0.5 # quitar 0.5 de arriba
plt.ylim(b, t) #actualizar
# Out:
# (2.5, -0.5)
